# %%
import pandas as pd
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials, SpotifyOAuth
import spotipy.util as util
import json, os
import config
from tqdm import tqdm

# %%
os.environ['SPOTIPY_CLIENT_ID']= config.CLIENT_ID
os.environ['SPOTIPY_CLIENT_SECRET']= config.CLIENT_SECRET
os.environ['SPOTIPY_REDIRECT_URI']='http://localhost:8081/callback'

# %%
username = config.USERNAME
scope = 'user-top-read'
token = util.prompt_for_user_token(username,scope)
sp = spotipy.Spotify(auth=token)

# %%
tracks = []
for j in tqdm(range(1960,2023)):
    for i in range(0,1000,50):
        try:
            results = sp.search(q='year:'+str(j), type='track', limit=50,offset=i) 
            tracks.extend(results['tracks']['items'])
        except:
            token = util.prompt_for_user_token(username,scope)
            sp = spotipy.Spotify(auth=token)
# Out:
# 100%|█████████████████████████████████████████████████████| 63/63 [11:05<00:00, 10.56s/it]

# %%
df_tracks = pd.DataFrame(tracks)

# %%
df_tracks.to_parquet('data/raw_data.parquet')
df_tracks.to_csv('data/raw_data.csv')

# %%
df_tracks['release_date'] = df_tracks['album'].apply(lambda x: x['release_date'])
df_tracks.head()
# Out:
#                                                album  \
# 0  {'album_type': 'album', 'artists': [{'external...
# 1  {'album_type': 'single', 'artists': [{'externa...
# 2  {'album_type': 'album', 'artists': [{'external...
# 3  {'album_type': 'single', 'artists': [{'externa...
# 4  {'album_type': 'compilation', 'artists': [{'ex...
#
#                                              artists  \
# 0  [{'external_urls': {'spotify': 'https://open.s...
# 1  [{'external_urls': {'spotify': 'https://open.s...
# 2  [{'external_urls': {'spotify': 'https://open.s...
# 3  [{'external_urls': {'spotify': 'https://open.s...
# 4  [{'external_urls': {'spotify': 'https://open.s...
#
#                                    available_markets  disc_number  \
# 0                                               [IN]            1
# 1                                               [IN]            1
# 2  [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...            1
# 3                                               [IN]            1
# 4                                               [IN]            1
#
#    duration_ms  explicit              external_ids  \
# 0       280080     False  {'isrc': 'INH109350700'}
# 1       169933     False  {'isrc': 'INH100367800'}
# 2       179693     False  {'isrc': 'USMC16046323'}
# 3       423013     False  {'isrc': 'INH100407396'}
# 4       163360     False  {'isrc': 'INH100305220'}
#
#                                        external_urls  \
# 0  {'spotify': 'https://open.spotify.com/track/4j...
# 1  {'spotify': 'https://open.spotify.com/track/5o...
# 2  {'spotify': 'https://open.spotify.com/track/4H...
# 3  {'spotify': 'https://open.spotify.com/track/1x...
# 4  {'spotify': 'https://open.spotify.com/track/7p...
#
#                                                 href                      id  \
# 0  https://api.spotify.com/v1/tracks/4jDfPSa6zoZ4...  4jDfPSa6zoZ4xGTSmyrg8i
# 1  https://api.spotify.com/v1/tracks/5o4crBlWt8lQ...  5o4crBlWt8lQnLMfPmkzQS
# 2  https://api.spotify.com/v1/tracks/4Hhv2vrOTy89...  4Hhv2vrOTy89HFRcjU3QOx
# 3  https://api.spotify.com/v1/tracks/1xjO1qiSWdRo...  1xjO1qiSWdRoK4TXIR6PeJ
# 4  https://api.spotify.com/v1/tracks/7pCiEvG73gNj...  7pCiEvG73gNjyq6UdIUDYE
#
#    is_local                            name  popularity  \
# 0     False  Khoya Khoya Chand Khula Aasman          35
# 1     False             Ei Meghla Dine Ekla          39
# 2     False                         At Last          78
# 3     False            Majhe Maher Pandhari          35
# 4     False                         Dolayam          35
#
#                                          preview_url  track_number   type  \
# 0  https://p.scdn.co/mp3-preview/1a63edf3b91501be...             8  track
# 1  https://p.scdn.co/mp3-preview/fe7b58cc9fce8008...             3  track
# 2                                               None             7  track
# 3  https://p.scdn.co/mp3-preview/82ba8bafc7bbe0b4...             3  track
# 4  https://p.scdn.co/mp3-preview/21974165673973e4...             5  track
#
#                                     uri release_date
# 0  spotify:track:4jDfPSa6zoZ4xGTSmyrg8i   1960-01-01
# 1  spotify:track:5o4crBlWt8lQnLMfPmkzQS   1960-12-31
# 2  spotify:track:4Hhv2vrOTy89HFRcjU3QOx         1960
# 3  spotify:track:1xjO1qiSWdRoK4TXIR6PeJ   1960-08-04
# 4  spotify:track:7pCiEvG73gNjyq6UdIUDYE   1960-04-08

# %%
df_audio_features = pd.DataFrame(columns=list(sp.audio_features(df_tracks['id'].values[:1])[0].keys()))
for i in tqdm(range(0,len(df_tracks),100)):
    try:
        df_audio_features = pd.concat([df_audio_features,pd.DataFrame(sp.audio_features(df_tracks.loc[i:i+99,'id'].values))],ignore_index=True)
    except:
        pass
# Out:
# 100%|███████████████████████████████████████████████████| 630/630 [03:02<00:00,  3.45it/s]

# %%
df = df_tracks.merge(df_audio_features,on='id',how='left')
df
# Out:
#                                                    album  \
# 0      {'album_type': 'album', 'artists': [{'external...
# 1      {'album_type': 'single', 'artists': [{'externa...
# 2      {'album_type': 'album', 'artists': [{'external...
# 3      {'album_type': 'single', 'artists': [{'externa...
# 4      {'album_type': 'compilation', 'artists': [{'ex...
# ...                                                  ...
# 62995  {'album_type': 'single', 'artists': [{'externa...
# 62996  {'album_type': 'album', 'artists': [{'external...
# 62997  {'album_type': 'single', 'artists': [{'externa...
# 62998  {'album_type': 'single', 'artists': [{'externa...
# 62999  {'album_type': 'single', 'artists': [{'externa...
#
#                                                  artists  \
# 0      [{'external_urls': {'spotify': 'https://open.s...
# 1      [{'external_urls': {'spotify': 'https://open.s...
# 2      [{'external_urls': {'spotify': 'https://open.s...
# 3      [{'external_urls': {'spotify': 'https://open.s...
# 4      [{'external_urls': {'spotify': 'https://open.s...
# ...                                                  ...
# 62995  [{'external_urls': {'spotify': 'https://open.s...
# 62996  [{'external_urls': {'spotify': 'https://open.s...
# 62997  [{'external_urls': {'spotify': 'https://open.s...
# 62998  [{'external_urls': {'spotify': 'https://open.s...
# 62999  [{'external_urls': {'spotify': 'https://open.s...
#
#                                        available_markets  disc_number  \
# 0                                                   [IN]            1
# 1                                                   [IN]            1
# 2      [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...            1
# 3                                                   [IN]            1
# 4                                                   [IN]            1
# ...                                                  ...          ...
# 62995  [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...            1
# 62996  [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...            1
# 62997  [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...            1
# 62998  [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...            1
# 62999  [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...            1
#
#        duration_ms_x  explicit              external_ids  \
# 0             280080     False  {'isrc': 'INH109350700'}
# 1             169933     False  {'isrc': 'INH100367800'}
# 2             179693     False  {'isrc': 'USMC16046323'}
# 3             423013     False  {'isrc': 'INH100407396'}
# 4             163360     False  {'isrc': 'INH100305220'}
# ...              ...       ...                       ...
# 62995         224000     False  {'isrc': 'DGA072235824'}
# 62996         212857     False  {'isrc': 'FR10S2274897'}
# 62997         200571     False  {'isrc': 'FRX762230302'}
# 62998         216000     False  {'isrc': 'FRX452213231'}
# 62999         194966     False  {'isrc': 'ING642203891'}
#
#                                            external_urls  \
# 0      {'spotify': 'https://open.spotify.com/track/4j...
# 1      {'spotify': 'https://open.spotify.com/track/5o...
# 2      {'spotify': 'https://open.spotify.com/track/4H...
# 3      {'spotify': 'https://open.spotify.com/track/1x...
# 4      {'spotify': 'https://open.spotify.com/track/7p...
# ...                                                  ...
# 62995  {'spotify': 'https://open.spotify.com/track/2t...
# 62996  {'spotify': 'https://open.spotify.com/track/6p...
# 62997  {'spotify': 'https://open.spotify.com/track/0F...
# 62998  {'spotify': 'https://open.spotify.com/track/32...
# 62999  {'spotify': 'https://open.spotify.com/track/6B...
#
#                                                     href  \
# 0      https://api.spotify.com/v1/tracks/4jDfPSa6zoZ4...
# 1      https://api.spotify.com/v1/tracks/5o4crBlWt8lQ...
# 2      https://api.spotify.com/v1/tracks/4Hhv2vrOTy89...
# 3      https://api.spotify.com/v1/tracks/1xjO1qiSWdRo...
# 4      https://api.spotify.com/v1/tracks/7pCiEvG73gNj...
# ...                                                  ...
# 62995  https://api.spotify.com/v1/tracks/2tGrx6LISSak...
# 62996  https://api.spotify.com/v1/tracks/6pprRG4zENBw...
# 62997  https://api.spotify.com/v1/tracks/0F7XXCXum92w...
# 62998  https://api.spotify.com/v1/tracks/326eZ9C7qpDj...
# 62999  https://api.spotify.com/v1/tracks/6BAC179SxuV3...
#
#                            id  ...  instrumentalness liveness  valence  \
# 0      4jDfPSa6zoZ4xGTSmyrg8i  ...          0.000017   0.5080    0.742
# 1      5o4crBlWt8lQnLMfPmkzQS  ...          0.588000   0.1130    0.711
# 2      4Hhv2vrOTy89HFRcjU3QOx  ...          0.013300   0.3340    0.328
# 3      1xjO1qiSWdRoK4TXIR6PeJ  ...          0.001060   0.0806    0.672
# 4      7pCiEvG73gNjyq6UdIUDYE  ...          0.000003   0.6030    0.697
# ...                       ...  ...               ...      ...      ...
# 62995  2tGrx6LISSakaJmU399mau  ...          0.000000   0.0749    0.624
# 62996  6pprRG4zENBwRbIbsGHWRM  ...          0.000000   0.0677    0.780
# 62997  0F7XXCXum92wXkBhYd25Ds  ...          0.000000   0.0988    0.672
# 62998  326eZ9C7qpDj6NSsEiKvoW  ...          0.000006   0.1830    0.688
# 62999  6BAC179SxuV3Z8Ediv8DXV  ...          0.000002   0.1770    0.703
#
#          tempo          type_y                                 uri_y  \
# 0       81.369  audio_features  spotify:track:4jDfPSa6zoZ4xGTSmyrg8i
# 1      115.920  audio_features  spotify:track:5o4crBlWt8lQnLMfPmkzQS
# 2       87.430  audio_features  spotify:track:4Hhv2vrOTy89HFRcjU3QOx
# 3      112.476  audio_features  spotify:track:1xjO1qiSWdRoK4TXIR6PeJ
# 4      171.294  audio_features  spotify:track:7pCiEvG73gNjyq6UdIUDYE
# ...        ...             ...                                   ...
# 62995  135.037  audio_features  spotify:track:2tGrx6LISSakaJmU399mau
# 62996   80.408  audio_features  spotify:track:6pprRG4zENBwRbIbsGHWRM
# 62997  139.962  audio_features  spotify:track:0F7XXCXum92wXkBhYd25Ds
# 62998  144.026  audio_features  spotify:track:326eZ9C7qpDj6NSsEiKvoW
# 62999  139.974  audio_features  spotify:track:6BAC179SxuV3Z8Ediv8DXV
#
#                                               track_href  \
# 0      https://api.spotify.com/v1/tracks/4jDfPSa6zoZ4...
# 1      https://api.spotify.com/v1/tracks/5o4crBlWt8lQ...
# 2      https://api.spotify.com/v1/tracks/4Hhv2vrOTy89...
# 3      https://api.spotify.com/v1/tracks/1xjO1qiSWdRo...
# 4      https://api.spotify.com/v1/tracks/7pCiEvG73gNj...
# ...                                                  ...
# 62995  https://api.spotify.com/v1/tracks/2tGrx6LISSak...
# 62996  https://api.spotify.com/v1/tracks/6pprRG4zENBw...
# 62997  https://api.spotify.com/v1/tracks/0F7XXCXum92w...
# 62998  https://api.spotify.com/v1/tracks/326eZ9C7qpDj...
# 62999  https://api.spotify.com/v1/tracks/6BAC179SxuV3...
#
#                                             analysis_url  duration_ms_y  \
# 0      https://api.spotify.com/v1/audio-analysis/4jDf...         280080
# 1      https://api.spotify.com/v1/audio-analysis/5o4c...         169933
# 2      https://api.spotify.com/v1/audio-analysis/4Hhv...         179693
# 3      https://api.spotify.com/v1/audio-analysis/1xjO...         423013
# 4      https://api.spotify.com/v1/audio-analysis/7pCi...         163360
# ...                                                  ...            ...
# 62995  https://api.spotify.com/v1/audio-analysis/2tGr...         224000
# 62996  https://api.spotify.com/v1/audio-analysis/6ppr...         212857
# 62997  https://api.spotify.com/v1/audio-analysis/0F7X...         200571
# 62998  https://api.spotify.com/v1/audio-analysis/326e...         216000
# 62999  https://api.spotify.com/v1/audio-analysis/6BAC...         194966
#
#        time_signature
# 0                   4
# 1                   3
# 2                   3
# 3                   4
# 4                   4
# ...               ...
# 62995               3
# 62996               4
# 62997               4
# 62998               4
# 62999               4
#
# [63000 rows x 35 columns]

# %%
for i,val in df[df.danceability.isnull()].iterrows():
    try:
        obj = sp.audio_features(df.loc[i,'id'])[0]
        del obj['id']
        df.loc[i,df.columns[len(df_tracks.columns):]] = list(obj.values())
    except:
        pass

# %%
df.to_parquet('data/raw_data.parquet')
df.to_csv('data/raw_data.csv',index=False)
